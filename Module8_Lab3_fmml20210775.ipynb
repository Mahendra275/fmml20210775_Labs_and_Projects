# %% [markdown]
# <a href="https://colab.research.google.com/github/Mahendra275/fmml20210775_Labs_and_Projects/blob/main/Module8_Lab3_fmml20210775.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2022-06-13 15:25:35--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   305MB/s    in 0.2s
#
# 2022-06-13 15:25:38 (305 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 25579  1510.02906v1  Robust online multi-person tracking requires t...    cs
# 24440   1312.5402v1  We investigate multiple techniques to improve ...    cs
# 9522   1607.08665v1  As robots aspire for long-term autonomous oper...    cs
# 12553  1802.09707v1  State-of-the-art deep neural networks are know...  stat
# 15271   1003.1399v1  Developers express the meaning of the domain i...    cs
# ...             ...                                                ...   ...
# 27808  1704.06020v2  Despite the promising progress made in recent ...    cs
# 24865   1412.4313v2  We present a two-module approach to semantic s...    cs
# 23760   1406.0312v1  State-of-the-art patch-based image representat...    cs
# 11189   1412.1576v1  When building large-scale machine learning (ML...  stat
# 115    1705.08557v1  In this work, we present the Grounded Recurren...  stat
#
#                                                    title  year  \
# 25579  Temporal Dynamic Appearance Modeling for Onlin...  2015
# 24440  Some Improvements on Deep Convolutional Neural...  2013
# 9522   Introspective Perception: Learning to Predict ...  2016
# 12553  Understanding and Enhancing the Transferabilit...  2018
# 15271  Automatic derivation of domain terms and conce...  2010
# ...                                                  ...   ...
# 27808  Enhancing Person Re-identification in a Self-t...  2017
# 24865  Combining the Best of Graphical Models and Con...  2014
# 23760                            Generalized Max Pooling  2014
# 11189  LightLDA: Big Topic Models on Modest Compute C...  2014
# 115                   Grounded Recurrent Neural Networks  2017
#
#                                                 keywords
# 25579  [associations, detection, responses, trajector...
# 24440  [investigate, techniques, convolutional, class...
# 9522   [autonomous, operations, environments, decisio...
# 12553  [vulnerable, adversarial, malicious, perturbat...
# 15271  [developers, specifically, identifiers, implem...
# ...                                                  ...
# 27808  [promising, identification, challenging, varia...
# 24865  [segmentation, incorporates, convolutional, gr...
# 23760  [representations, operation, aggregates, stati...
# 11189  [attempted, industrial, thousands, practitione...
# 115    [recurrent, recurrent, architecture, predictio...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 25579    [associations, detection, responses, trajector...
# 24440    [investigate, techniques, convolutional, class...
# 9522     [autonomous, operations, environments, decisio...
# 12553    [vulnerable, adversarial, malicious, perturbat...
# 15271    [developers, specifically, identifiers, implem...
#                                ...
# 3798     [approaches, architectures, significant, perfo...
# 17567    [multimodal, translation, modulates, processin...
# 12354    [performance, optimization, dimensional, regul...
# 27834    [motivated, detection, supermarkets, generatio...
# 22953    [classical, approaches, causality, detection, ...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8725 words.
# Out of those 4559 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="3e3405ca-e16f-4720-aade-3f9b8824a9ec" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3e3405ca-e16f-4720-aade-3f9b8824a9ec")) {                    Plotly.newPlot(                        "3e3405ca-e16f-4720-aade-3f9b8824a9ec",                        [{"x":["complement","trajectories","significantly","incorporating","usefulness","challenging","association","associations","variations","incrementally","characteristics","developing","appearance","detections","adjusting","discriminate","sequences","responses","framework","experiments","sufficient","algorithm","detection","parameters","structure","selection","outperforms","evaluating","affinities","alternatively","benchmark","measurement","different","algorithms","demonstrate","appearances","improvements","recognition","transformations","predictions","summarizes","improvement","resolution","classification","complementary","investigate","additional","techniques","challenge","convolutional","effectively","perception","ambiguous","situational","introspection","capability","direction","qualified","introspective","environments","decisions","autonomous","uncertain","operations","motivates","awareness","situations","vulnerable","architecture","malicious","application","adversarial","influence","perturbations","effectiveness","systematically","confirmed","including","especially","transferability","generated","constructing","enhancing","consequently","smoothness","adversary","understanding","effective","vocabulary","placement","localization","knowledge","following","comprehension","automatically","conducted","derivation","identifiers","automatic","characterize","developers","appropriate","specifically","evolution","frameworks","implemented","maintenance","independent","coefficients","processing","formulated","regularization","estimation","equivalent","regularized","solutions","technique","collection","reformulating","extensively","footprint","particularly","appealing","component","completion","factorization","implementation","decomposition","encouraging","regularizer","asymptotically","robustness","demonstrates","optimization","converges","important","underlying","stationary","numerical","typically","manipulating","penalties","nesterovs","relevance","breakthrough","approximate","predictive","smoothing","scattered","neuroimaging","variation","convergence","continuation","achieving","traditional","successively","minimizes","coherence","precision","perspectives","accelerated","parameter","penalization","necessarily","approaches","structural","irregular","multivariate","diagnosis","preserving","combination","prognosis","minimized","regression","prescribed","relationships","prediction","efficiently","recurrent","locations","implicitly","information","introduces","increased","potential","represented","convolution","computations","increases","alternative","increasing","tremendous","filtering","iteratively","practical","correspondence","experimental","deformations","transformation","continuous"],"y":[21,33,234,54,24,265,21,13,86,17,90,62,85,15,9,7,105,27,514,568,65,780,373,253,360,144,296,68,5,10,212,33,732,560,585,12,102,364,48,95,7,139,134,522,44,139,112,376,144,394,108,50,20,6,1,52,65,2,2,82,48,63,28,76,9,9,47,17,249,2,252,104,48,14,217,13,14,241,121,1,172,44,22,27,15,6,147,236,32,6,82,357,81,19,167,67,15,3,177,53,6,92,161,51,33,110,11,128,38,294,34,89,214,54,40,151,231,89,1,31,9,83,21,87,33,32,126,69,22,19,13,97,50,313,25,355,134,17,82,104,10,6,1,46,6,98,60,10,2,6,54,95,5,91,164,6,21,14,81,17,13,137,3,15,436,79,15,23,55,57,135,2,11,115,4,69,241,159,159,42,21,709,69,39,153,90,52,41,58,106,107,12,75,32,157,24,377,14,62,112],"type":"bar"},{"x":["complement","trajectories","significantly","incorporating","use ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4559,), (4559, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8358333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Towards</span> <span style=''>Faster</span> <span style=''>Training</span> <span style=''>of</span> <span style=''>Global</span> <span style='background-color:rgba(255, 0, 0, 0.5245901639344261);'>Covariance</span> <span style=''>Pooling</span> <span style=''>Networks</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Iterative</span> <span style=''>Matrix</span> <span style=''>Square</span> <span style=''>Root</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Normalization</span> <br/><br/><span style=''>Global</span> <span style='background-color:rgba(255, 0, 0, 0.5245901639344261);'>covariance</span> <span style=''>pooling</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.6554621848739495);'>Convolutional</span> <span style=''>neural</span> <span style=''>neworks</span> <span style=''>has</span> <span style=''>achieved</span> <span style='background-color:rgba(0, 255, 0, 0.5483870967741935);'>impressive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>improvement</span> <span style=''>over</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classical</span> <span style=''>first</span> <span style=''>order</span> <span style=''>pooling</span> <span style=''>Recent</span> <span style=''>works</span> <span style=''>have</span> <span style=''>shown</span> <span style=''>matrix</span> <span style=''>square</span> <span style=''>root</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>normalization</span> <span style=''>plays</span> <span style=''>a</span> <span style=''>central</span> <span style=''>role</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.338235294117647);'>achieving</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>However</span> <span style=''>existing</span> <span style=''>methods</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>depending</span> <span style=''>heavily</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.7272727272727274);'>eigenvalue</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>decomposition</span> <span style=''>(EIG)</span> <span style=''>or</span> <span style=''>singular</span> <span style=''>value</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>decomposition</span> <span style=''>(SVD)</span> <span style='background-color:rgba(0, 255, 0, 0.4285714285714285);'>suffering</span> <span style=''>from</span> <span style='background-color:rgba(0, 255, 0, 0.4545454545454546);'>inefficient</span> <span style=''>training</span> <span style=''>due</span> <span style=''>to</span> <span style=''>limited</span> <span style=''>support</span> <span style=''>of</span> <span style=''>EIG</span> <span style=''>and</span> <span style=''>SVD</span> <span style=''>on</span> <span style=''>GPU</span> <span style=''>Towards</span> <span style='background-color:rgba(0, 255, 0, 0.4193548387096775);'>addressing</span> <span style=''>this</span> <span style=''>problem</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>iterative</span> <span style=''>matrix</span> <span style=''>square</span> <span style=''>root</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>normalization</span> <span style=''>method</span> <span style=''>for</span> <span style=''>end</span> <span style=''>to</span> <span style=''>end</span> <span style=''>training</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.5245901639344261);'>covariance</span> <span style=''>pooling</span> <span style=''>networks</span> <span style=''>At</span> <span style=''>the</span> <span style=''>core</span> <span style=''>of</span> <span style=''>our</span> <span  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Deep</span> <span style=''>Directed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Generative</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Autoencoders</span> <br/><br/><span style=''>For</span> <span style=''>discrete</span> <span style=''>data</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>likelihood</span> <span style=''>P(x)</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>rewritten</span> <span style=''>exactly</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parametrized</span> <span style=''>into</span> <span style=''>P(X</span> <span style=''>x)</span> <span style=''>P(X</span> <span style=''>x</span> <span style=''>|</span> <span style=''>H</span> <span style=''>f(x))</span> <span style=''>P(H</span> <span style=''>f(x))</span> <span style=''>if</span> <span style=''>P(X</span> <span style=''>|</span> <span style=''>H)</span> <span style=''>has</span> <span style=''>enough</span> <span style=''>capacity</span> <span style=''>to</span> <span style=''>put</span> <span style=''>no</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probability</span> <span style=''>mass</span> <span style=''>on</span> <span style=''>any</span> <span style=''>x</span> <span style=''>for</span> <span style=''>which</span> <span style=''>f(x)neq</span> <span style=''>f(x)</span> <span style=''>where</span> <span style=''>f(cdot)</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>deterministic</span> <span style=''>discrete</span> <span style=''>function</span> <span style=''>The</span> <span style=''>log</span> <span style=''>of</span> <span style=''>the</span> <span style=''>first</span> <span style=''>factor</span> <span style=''>gives</span> <span style=''>rise</span> <span style=''>to</span> <span style=''>the</span> <span style=''>log</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>likelihood</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reconstruction</span> <span style=''>error</span> <span style=''>of</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>autoencoder</span> <span style=''>with</span> <span style=''>f(cdot)</span> <span style=''>as</span> <span style=''>the</span> <span style=''>encoder</span> <span style=''>and</span> <span style=''>P(X|H)</span> <span style=''>as</span> <span style=''>the</span> <span style=''>(probabilistic)</span> <span style=''>decoder</span> <span style=''>The</span> <span style=''>log</span> <span style=''>of</span> <span style=''>the</span> <span style=''>second</span> <span style=''>term</span> <span style=''>can</span> <span style=''>be</span> <span style=''>seen</span> <span style=''>as</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularizer</span> <span style=''>on</span> <span style=''>the</span> <span style=''>encoded</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>activations</span> <span style=''>hf(x)</span> <span style=''>eg</span> <span style=''>as</span> <span style=''>in</span> <span style=''>sparse</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>autoencoders</span> <span style=''>Both</span> <span style=''>encoder</span> <span style=''>and</span> <span style=''>decoder</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>represented</span> <span style=''>by</span> <span style=''>a</span> <span style=''>deep</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>and</span> <span style=''>trained</span> <span style=''>to</span> <span style=''>maximize</span> <span style=''>the</span> <span style=''>average</span> <span style=''>of</span> <span style=''>the</span> <span style=''>optimal</span> <span style=''>log</span> <span style='backgro ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Optimal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>amortized</span> <span style=''>regret</span> <span style=''>in</span> <span style=''>every</span> <span style=''>interval</span> <br/><br/><span style=''>Consider</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classical</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predicting</span> <span style=''>the</span> <span style=''>next</span> <span style=''>bit</span> <span style=''>in</span> <span style=''>a</span> <span style=''>sequence</span> <span style=''>of</span> <span style=''>bits</span> <span style=''>A</span> <span style=''>standard</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>measure</span> <span style=''>is</span> <span style=''>em</span> <span style=''>regret</span> <span style=''>(loss</span> <span style=''>in</span> <span style=''>payoff)</span> <span style=''>with</span> <span style=''>respect</span> <span style=''>to</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style=''>experts</span> <span style=''>For</span> <span style=''>example</span> <span style=''>if</span> <span style=''>we</span> <span style=''>measure</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>with</span> <span style=''>respect</span> <span style=''>to</span> <span style=''>two</span> <span style=''>constant</span> <span style=''>experts</span> <span style=''>one</span> <span style=''>that</span> <span style=''>always</span> <span style=''>predicts</span> <span style=''>0s</span> <span style=''>and</span> <span style=''>another</span> <span style=''>that</span> <span style=''>always</span> <span style=''>predicts</span> <span style=''>1s</span> <span style=''>it</span> <span style=''>is</span> <span style=''>well</span> <span style=''>known</span> <span style=''>that</span> <span style=''>one</span> <span style=''>can</span> <span style=''>get</span> <span style=''>regret</span> <span style=''>O(sqrt</span> <span style=''>T)</span> <span style=''>with</span> <span style=''>respect</span> <span style=''>to</span> <span style=''>the</span> <span style=''>best</span> <span style=''>expert</span> <span style=''>by</span> <span style=''>using</span> <span style=''>say</span> <span style=''>the</span> <span style=''>weighted</span> <span style=''>majority</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>But</span> <span style=''>this</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>does</span> <span style=''>not</span> <span style=''>provide</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>guarantee</span> <span style=''>in</span> <span style=''>any</span> <span style=''>interval</span> <span style=''>There</span> <span style=''>are</span> <span style=''>other</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>that</span> <span style=''>ensure</span> <span style=''>regret</span> <span style=''>O(sqrt</span> <span style=''>x</span> <span style=''>log</span> <span style=''>T)</span> <span style=''>in</span> <span style=''>any</span> <span style=''>interval</span> <span style=''>of</span> <span style=''>length</span> <span style=''>x</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>show</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>randomized</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>that</span> <span style=''>in</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>amortized</span> <span style=''>sense</span> <span style=''>gets</span> ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>better</span> <span style=''>Beta</span> <span style=''>for</span> <span style=''>the</span> <span style=''>H</span> <span style=''>measure</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <br/><br/><span style=''>The</span> <span style=''>area</span> <span style=''>under</span> <span style=''>the</span> <span style=''>ROC</span> <span style=''>curve</span> <span style=''>is</span> <span style=''>widely</span> <span style=''>used</span> <span style=''>as</span> <span style=''>a</span> <span style=''>measure</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>rules</span> <span style=''>However</span> <span style=''>it</span> <span style=''>has</span> <span style=''>recently</span> <span style=''>been</span> <span style=''>shown</span> <span style=''>that</span> <span style=''>the</span> <span style=''>measure</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>fundamentally</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>incoherent</span> <span style=''>in</span> <span style=''>the</span> <span style=''>sense</span> <span style=''>that</span> <span style=''>it</span> <span style=''>treats</span> <span style=''>the</span> <span style=''>relative</span> <span style=''>severities</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>misclassifications</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>differently</span> <span style=''>when</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifiers</span> <span style=''>are</span> <span style=''>used</span> <span style=''>To</span> <span style=''>overcome</span> <span style=''>this</span> <span style=''>Hand</span> <span style=''>(2009)</span> <span style=''>proposed</span> <span style=''>the</span> <span style=''>H</span> <span style=''>measure</span> <span style=''>which</span> <span style=''>allows</span> <span style=''>a</span> <span style=''>given</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>researcher</span> <span style=''>to</span> <span style=''>fix</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>of</span> <span style=''>relative</span> <span style=''>severities</span> <span style=''>to</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifier</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>independent</span> <span style=''>setting</span> <span style=''>on</span> <span style=''>a</span> <span style=''>given</span> <span style=''>problem</span> <span style=''>This</span> <span style=''>note</span> <span style=''>extends</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>discussion</span> <span style=''>and</span> <span style=''>proposes</span> <span style=''>a</span> <span style=''>modified</span> <span style=''>standard</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>for</span> <span style=''>the</span> <span style=''>H</span> <span style=''>measure</span> <span style=''>which</span> <span style=''>better</span> <span style=''>matches</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>requirements</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>researchers</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particular</span> <span style=''>those</span> <span style=''>faced</span> <span style=''>with</span> <span style=''>heavily</span> <span style='background-c ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	experimental (0.13585585585585586)
# 	processing (0.10594594594594595)
# 	knowledge (0.12864864864864864)
# 	architecture (0.08972972972972973)
# 	information (0.2554954954954955)
# 	segmentation (0.07747747747747748)
# 	different (0.2637837837837838)
# 	detection (0.1344144144144144)
# 	recognition (0.13117117117117116)
# 	convolutional (0.14198198198198198)
#
# Some Statistics words are:
# 	stochastic (0.1308641975308642)
# 	statistical (0.14814814814814814)
# 	variables (0.14123456790123456)
# 	estimation (0.17185185185185184)
# 	distribution (0.174320987654321)
# 	theoretical (0.15259259259259259)
# 	inference (0.18765432098765433)
# 	algorithm (0.397037037037037)
# 	dimensional (0.19160493827160494)
# 	regression (0.1688888888888889)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="ab5b7cad-9106-4e6e-ad50-9c7aedacf37f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ab5b7cad-9106-4e6e-ad50-9c7aedacf37f")) {                    Plotly.newPlot(                        "ab5b7cad-9106-4e6e-ad50-9c7aedacf37f",                        [{"x":["complement","trajectories","significantly","incorporating","usefulness","challenging","association","associations","variations","incrementally","characteristics","developing","appearance","detections","adjusting","discriminate","sequences","responses","framework","experiments","sufficient","algorithm","detection","parameters","structure","selection","outperforms","evaluating","affinities","alternatively","benchmark","measurement","different","algorithms","demonstrate","appearances","improvements","recognition","transformations","predictions","summarizes","improvement","resolution","classification","complementary","investigate","additional","techniques","challenge","convolutional","effectively","perception","ambiguous","situational","introspection","capability","direction","qualified","introspective","environments","decisions","autonomous","uncertain","operations","motivates","awareness","situations","vulnerable","architecture","malicious","application","adversarial","influence","perturbations","effectiveness","systematically","confirmed","including","especially","transferability","generated","constructing","enhancing","consequently","smoothness","adversary","understanding","effective","vocabulary","placement","localization","knowledge","following","comprehension","automatically","conducted","derivation","identifiers","automatic","characterize","developers","appropriate","specifically","evolution","frameworks","implemented","maintenance","independent","coefficients","processing","formulated","regularization","estimation","equivalent","regularized","solutions","technique","collection","reformulating","extensively","footprint","particularly","appealing","component","completion","factorization","implementation","decomposition","encouraging","regularizer","asymptotically","robustness","demonstrates","optimization","converges","important","underlying","stationary","numerical","typically","manipulating","penalties","nesterovs","relevance","breakthrough","approximate","predictive","smoothing","scattered","neuroimaging","variation","convergence","continuation","achieving","traditional","successively","minimizes","coherence","precision","perspectives","accelerated","parameter","penalization","necessarily","approaches","structural","irregular","multivariate","diagnosis","preserving","combination","prognosis","minimized","regression","prescribed","relationships","prediction","efficiently","recurrent","locations","implicitly","information","introduces","increased","potential","represented","convolution","computations","increases","alternative","increasing","tremendous","filtering","iteratively","practical","correspondence","experimental","deformations","transformation","continuous","semantically","benchmarks","descriptor","associated","geometric","sentences","representations","comparing","successor","abstraction","successive","automated","character","selecting","empirical","generation","generating","translation","minimizing","preprocessing","decompose","everything","nonnegative","dictionary","objective","comparisons","factorizations","efficiency","stochastic","observation","extension","reinforcement","behaviours","programming","artificial","interface","platforms","configuration","simulated","transferred","successfully","simulation","mechanism","condition","statistical","parametrization","quantitative","predicting","conclusions","represents","identified","graphical","identification","equations","c ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	neuroscientists
# 	majorizer
# 	oscillates
# 	unbiasedness
# 	measurable
# 	discriminable
# 	dendrogram
# 	exogenous
# 	suggestion
# 	sparsifying
# 	horseshoe
# 	investing
# 	detailing
# 	stabilizing
# 	clarifies
# 	shrinking
# 	recurring
# 	durations
# 	stragglers
# 	textitnot
# Some words which never appear in Statistics papers:
# 	detections
# 	situational
# 	qualified
# 	introspective
# 	awareness
# 	identifiers
# 	developers
# 	everything
# 	elevation
# 	referenced
# 	morphemes
# 	pansharpening
# 	radiometric
# 	radiologists
# 	undecidable
# 	recognizers
# 	decidable
# 	mathcalel
# 	occlusions
# 	pathology

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.095112816862175e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7941666666666667
